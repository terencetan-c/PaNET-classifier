# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/fdp54928/Documents/PaNET-classifier/baseline_model2/scibert_panet_results2/per_seed_results.csv')

# %%
df
# Out:
#    Unnamed: 0  test_loss  test_f1_micro  test_f1_macro  test_hF1  \
# 0          42   0.078766       0.839888       0.372253  0.839895
# 1           1   0.078845       0.840906       0.379285  0.840462
# 2           2   0.078935       0.840670       0.371014  0.840676
# 3           3   0.079194       0.839673       0.379479  0.839558
# 4           4   0.079131       0.839961       0.374028  0.839885
#
#    test_f1_micro_ci_lower  test_f1_micro_ci_upper  test_f1_macro_ci_lower  \
# 0                0.826401                0.852754                0.353662
# 1                0.826784                0.853854                0.359679
# 2                0.826990                0.853643                0.351802
# 3                0.825603                0.853365                0.356879
# 4                0.826208                0.853170                0.354943
#
#    test_f1_macro_ci_upper  test_hf1_ci_lower  test_hf1_ci_upper  test_runtime  \
# ...

# %%
for metric in ['test_f1_micro', 'test_f1_macro', 'test_hF1']:
    vals = df[metric].values.astype(float)
    print(f"{metric}: {np.mean(vals):.4f} ± {np.std(vals):.4f}")
# Out:
# test_f1_micro: 0.8402 ± 0.0005
# test_f1_macro: 0.3752 ± 0.0035
# test_hF1: 0.8401 ± 0.0004
